# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ## Read and evaluate the following problem statement:
# Determine which free-tier customers will convert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer usage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: free customer becomes paying (y/n)

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [markdown]
# Answer: age, gender, location, profession, last day since log in; days since last log in, activity score

# %% [markdown]
# #### 3. What timeframe is this data relevant for?

# %% [markdown]
# Answer: Jan-Apr 2015

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: demographic and customer usage data will allow us to predict which non-paying customers convert to paying customers

# %% [markdown]
# ## Let's get started with our `admissions.csv` dataset

# %% [markdown]
# #### 1. Create a data dictionary

# %% [markdown]
# Answer:
#
# import coors.csv with open('admissions.csv', mode='r') as infile:
#     reader = csv.reader(infile)
#     with open('admissions_new.csv', mode='w') as outfile:
#     writer = csv.writer(outfile)
#     for rows in reader:
#         k = rows[0]
#         v = rows[1]
#         mydict = {k:v for k, v in rows}
#     print(mydict)
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Var 1 | 0 = not thing 1 = thing | categorical
# Var 2 | thing in unit X | continuous
# Var 3

# %% [markdown]
# #We would like to explore the association between X and Y

# %% [markdown]
# #### 2. What is the outcome?

# %% [markdown]
# Answer: admit(in or out)

# %% [markdown]
# #### 3. What are the predictors/covariates?

# %% [markdown]
# Answer: GPA, GRE, Prestige

# %% [markdown]
# #### 4. What timeframe is this data relevant for?

# %% [markdown]
# Answer:That year's admissions cycle

# %% [markdown]
# #### 5. What is the hypothesis?

# %% [markdown]
# Answer: higher GPA, higher GRE, higher prestige= higher likelihood for acceptance

# %% [markdown]
# #### 6. Using the above information, write a well-formed problem statement.

# %% [markdown]
# Answer: UCLA wants to accept the most qualified candidates from its application pool.
#
#         UCLA Is currently favoring high scores over prestige, and must decide if prestige is irrelevant to success or         needs to be weighted more heavily in their considerations

# %% [markdown]
# ### Exploratory Analysis Plan

# %% [markdown]
# Using the lab from a class as a guide, create an exploratory analysis plan.

# %% [markdown]
# #### 1. What are the goals of the exploratory analysis?

# %% [markdown]
# Answer: Determine which covariates have the strongest correlation with acceptance. Determine if there are admissions data points that have no or little bearing on acceptance. See if there is a 'most robust' acceptance indicator

# %% [markdown]
# #### 2a. What are the assumptions regarding the distribution of the data?

# %% [markdown]
# Answer: Acceptance rates will be skewed towards higher GPA, higher GRE, and 'lower' class rank. I assume that UCLA will pick most of the 3rd and 4th quartile, and a small portion of scorers below median depending on the stat

# %% [markdown]
# #### 2b. How will you determine the distribution of your data?

# %% [markdown]
# Answer: Scatter plot: GPA on x axis, GRE on y axis. o's for acceptance, x for denials.  Perhaps a histogram of 'accepted' students at each point of the spectrum on the respective test.

# %% [markdown]
# #### 3a. How might outliers impact your analysis?

# %% [markdown]
# Answer: They could pull the median in one direction or the other

# %% [markdown]
# #### 3b. How will you test for outliers?

# %% [markdown]
# Answer: set parameters for test scores- if anything is higher than the max score on the test is bad data.

# %% [markdown]
# #### 4. What is your exploratory analysis plan?
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.

# %% [markdown]
# Answer: Using scatterplots, histograms, and linear regressions we will test the independent variables of GPA, GRE score, Class rank against the dependent variable of acceptance.
#
# In one year, run the same tests but against the "current class rank" to see which covariates were best at predicting success when on campus.

# %% [markdown]
# ## Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('admissions.csv', sep=',')
df.head(400)
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %%
df.to_dict(orient="index")
# Out:
# {0: {'admit': 0.0, 'gpa': 3.6099999999999999, 'gre': 380.0, 'prestige': 3.0},
#  1: {'admit': 1.0, 'gpa': 3.6699999999999999, 'gre': 660.0, 'prestige': 3.0},
#  2: {'admit': 1.0, 'gpa': 4.0, 'gre': 800.0, 'prestige': 1.0},
#  3: {'admit': 1.0, 'gpa': 3.1899999999999999, 'gre': 640.0, 'prestige': 4.0},
#  4: {'admit': 0.0, 'gpa': 2.9300000000000002, 'gre': 520.0, 'prestige': 4.0},
#  5: {'admit': 1.0, 'gpa': 3.0, 'gre': 760.0, 'prestige': 2.0},
#  6: {'admit': 1.0, 'gpa': 2.98, 'gre': 560.0, 'prestige': 1.0},
#  7: {'admit': 0.0, 'gpa': 3.0800000000000001, 'gre': 400.0, 'prestige': 2.0},
#  8: {'admit': 1.0, 'gpa': 3.3900000000000001, 'gre': 540.0, 'prestige': 3.0},
#  9: {'admit': 0.0, 'gpa': 3.9199999999999999, 'gre': 700.0, 'prestige': 2.0},
#  10: {'admit': 0.0, 'gpa': 4.0, 'gre': 800.0, 'prestige': 4.0},
#  11: {'admit': 0.0, 'gpa': 3.2200000000000002, 'gre': 440.0, 'prestige': 1.0},
#  12: {'admit': 1.0, 'gpa': 4.0, 'gre': 760.0, 'prestige': 1.0},
# ...
